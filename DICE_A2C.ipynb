# %%
import numpy as np
np.set_printoptions(suppress=True)
import time
from numba import njit,guvectorize,float64
import scipy.optimize as opt
from matplotlib import pyplot as plt
import math
#Set
t = np.arange(1, 101)
NT = len(t)

# %%
#Parameters
fosslim = 6000 # Maximum cumulative extraction fossil fuels (GtC); denoted by CCum
tstep  = 5 # Years per Period
ifopt  = 0 # Indicator where optimized is 1 and base is 0

# %%
#Preferences

elasmu = 1.45 #  Elasticity of marginal utility of consumption
prstp = 0.015 #   Initial rate of social time preference per year 

#** Population and technology
gama  = 0.300 #   Capital elasticity in production function         /.300 /
pop0  = 7403   # Initial world population 2015 (millions)          /7403 /
popadj = 0.134 #  Growth rate to calibrate to 2050 pop projection  /0.134/
popasym = 11500 # Asymptotic population (millions)                 /11500/
dk  = 0.100 #     Depreciation rate on capital (per year)           /.100 /
q0  = 105.5 #     Initial world gross output 2015 (trill 2010 USD) /105.5/
k0  = 223 #     Initial capital value 2015 (trill 2010 USD)        /223  /
a0  = 5.115 #     Initial level of total factor productivity       /5.115/
ga0  = 0.076 #    Initial growth rate for TFP per 5 years          /0.076/
dela  = 0.005 #   Decline rate of TFP per 5 years                  /0.005/

#** Emissions parameters
gsigma1  = -0.0152 # Initial growth of sigma (per year)            /-0.0152/
dsig  = -0.001 #   Decline rate of decarbonization (per period)    /-0.001 /
eland0 = 2.6 #  Carbon emissions from land 2015 (GtCO2 per year)   / 2.6   /
deland = 0.115 # Decline rate of land emissions (per period)        / .115  /
e0 = 35.85 #    Industrial emissions 2015 (GtCO2 per year)       /35.85  /
miu0  = 0.03 #   Initial emissions control rate for base case 2015  /.03    /

#** Carbon cycle
#* Initial Conditions
mat0 = 851 #  Initial Concentration in atmosphere 2015 (GtC)       /851  /
mu0  = 460 #  Initial Concentration in upper strata 2015 (GtC)     /460  /
ml0  = 1740 #  Initial Concentration in lower strata 2015 (GtC)    /1740 /
mateq = 588 # mateq Equilibrium concentration atmosphere  (GtC)    /588  /
mueq  = 360 # mueq Equilibrium concentration in upper strata (GtC) /360  /
mleq = 1720 # mleq Equilibrium concentration in lower strata (GtC) /1720 /

#* Flow paramaters, denoted by Phi_ij in the model
b12  = 0.12 #    Carbon cycle transition matrix                     /.12  /
b23  = 0.007 #   Carbon cycle transition matrix                    /0.007/
#* These are for declaration and are defined later
b11  = None   # Carbon cycle transition matrix
b21  = None  # Carbon cycle transition matrix
b22  = None  # Carbon cycle transition matrix
b32  = None  # Carbon cycle transition matrix
b33  = None  # Carbon cycle transition matrix
sig0  = None  # Carbon intensity 2010 (kgCO2 per output 2005 USD 2010)

#** Climate model parameters
t2xco2  = 3.1 # Equilibrium temp impact (oC per doubling CO2)    / 3.1 /
fex0  = 0.5 #   2015 forcings of non-CO2 GHG (Wm-2)              / 0.5 /
fex1  = 1.0 #   2100 forcings of non-CO2 GHG (Wm-2)              / 1.0 /
tocean0  = 0.0068 # Initial lower stratum temp change (C from 1900) /.0068/
tatm0  = 0.85 #  Initial atmospheric temp change (C from 1900)    /0.85/
c1  = 0.1005 #     Climate equation coefficient for upper level  /0.1005/
c3  = 0.088 #     Transfer coefficient upper to lower stratum    /0.088/
c4  = 0.025 #     Transfer coefficient for lower level           /0.025/
fco22x  = 3.6813 # eta in the model; Eq.22 : Forcings of equilibrium CO2 doubling (Wm-2)   /3.6813 /

#** Climate damage parameters
a10  = 0 #     Initial damage intercept                         /0   /
a20  = None #     Initial damage quadratic term
a1  = 0 #      Damage intercept                                 /0   /
a2  = 0.00236 #      Damage quadratic term                     /0.00236/
a3  = 2.00 #      Damage exponent                              /2.00   /

#** Abatement cost
expcost2 = 2.6 # Theta2 in the model, Eq. 10 Exponent of control cost function             / 2.6  /
pback  = 550 #   Cost of backstop 2010$ per tCO2 2015          / 550  /
gback  = 0.025 #   Initial cost decline backstop cost per period / .025/
limmiu  = 1.2 #  Upper limit on control rate after 2150        / 1.2 /
tnopol  = 45 #  Period before which no emissions controls base  / 45   /
cprice0  = 2 # Initial base carbon price (2010$ per tCO2)      / 2    /
gcprice  = 0.02 # Growth rate of base carbon price per year     /.02  /

#** Scaling and inessential parameters
#* Note that these are unnecessary for the calculations
#* They ensure that MU of first period's consumption =1 and PV cons = PV utilty
scale1  = 0.0302455265681763 #    Multiplicative scaling coefficient           /0.0302455265681763 /
scale2  = -10993.704 #    Additive scaling coefficient       /-10993.704/;

# %%
#* Parameters for long-run consistency of carbon cycle 
#(Question)
b11 = 1 - b12
b21 = b12*mateq/mueq
b22 = 1 - b21 - b23
b32 = b23*mueq/mleq
b33 = 1 - b32

#* Further definitions of parameters
a20 = a2
sig0 = e0/(q0*(1-miu0)) #From Eq. 14
lam = fco22x/ t2xco2 #From Eq. 25

l = np.zeros(NT)
l[0] = pop0 #Labor force
al = np.zeros(NT) 
al[0] = a0
gsig = np.zeros(NT) 
gsig[0] = gsigma1
sigma = np.zeros(NT)
sigma[0]= sig0
ga = ga0 * np.exp(-dela*5*(t-1)) #TFP growth rate dynamics, Eq. 7
pbacktime = pback * (1-gback)**(t-1) #Backstop price
etree = eland0*(1-deland)**(t-1) #Emissions from deforestration
rr = 1/((1+prstp)**(tstep*(t-1))) #Eq. 3
#The following three equations define the exogenous radiative forcing; used in Eq. 23  
forcoth = np.full(NT,fex0)
forcoth[0:18] = forcoth[0:18] + (1/17)*(fex1-fex0)*(t[0:18]-1)
forcoth[18:NT] = forcoth[18:NT] + (fex1-fex0)
optlrsav = (dk + .004)/(dk + .004*elasmu + prstp)*gama #Optimal long-run savings rate used for transversality (Question)
cost1 = np.zeros(NT)
cumetree = np.zeros(NT)
cumetree[0] = 100
cpricebase = cprice0*(1+gcprice)**(5*(t-1))

# %%
@njit('(float64[:], int32)')
def InitializeLabor(il,iNT):
    for i in range(1,iNT):
        il[i] = il[i-1]*(popasym / il[i-1])**popadj

@njit('(float64[:], int32)')        
def InitializeTFP(ial,iNT):
    for i in range(1,iNT):
        ial[i] = ial[i-1]/(1-ga[i-1])
        
@njit('(float64[:], int32)')        
def InitializeGrowthSigma(igsig,iNT):
    for i in range(1,iNT):
        igsig[i] = igsig[i-1]*((1+dsig)**tstep)
        
@njit('(float64[:], float64[:],float64[:],int32)')        
def InitializeSigma(isigma,igsig,icost1,iNT):
    for i in range(1,iNT):
        isigma[i] =  isigma[i-1] * np.exp(igsig[i-1] * tstep)
        icost1[i] = pbacktime[i] * isigma[i]  / expcost2 /1000
        
@njit('(float64[:], int32)')        
def InitializeCarbonTree(icumetree,iNT):
    for i in range(1,iNT):
        icumetree[i] = icumetree[i-1] + etree[i-1]*(5/3.666)

# %%
"""
Functions of the model
"""

"""
First: Functions related to emissions of carbon and weather damages
"""

# Retuns the total carbon emissions; Eq. 18
@njit('float64(float64[:],int32)') 
def fE(iEIND,index):
    return iEIND[index] + etree[index]

#Eq.14: Determines the emission of carbon by industry EIND
@njit('float64(float64[:],float64[:],float64[:],int32)') 
def fEIND(iYGROSS, iMIU, isigma,index):
    return isigma[index] * iYGROSS[index] * (1 - iMIU[index])

#Cumulative industrial emission of carbon
@njit('float64(float64[:],float64[:],int32)') 
def fCCA(iCCA,iEIND,index):
    return iCCA[index-1] + iEIND[index-1] * 5 / 3.666

#Cumulative total carbon emission
@njit('float64(float64[:],float64[:],int32)')
def fCCATOT(iCCA,icumetree,index):
    return iCCA[index] + icumetree[index]

#Eq. 22: the dynamics of the radiative forcing
@njit('float64(float64[:],int32)')
def fFORC(iMAT,index):
    return fco22x * np.log(iMAT[index]/588.000)/np.log(2) + forcoth[index]

# Dynamics of Omega; Eq.9
@njit('float64(float64[:],int32)')
def fDAMFRAC(iTATM,index):
    return a1*iTATM[index] + a2*iTATM[index]**a3

#Calculate damages as a function of Gross industrial production; Eq.8 
@njit('float64(float64[:],float64[:],int32)')
def fDAMAGES(iYGROSS,iDAMFRAC,index):
    return iYGROSS[index] * iDAMFRAC[index]

#Dynamics of Lambda; Eq. 10 - cost of the reudction of carbon emission (Abatement cost)
@njit('float64(float64[:],float64[:],float64[:],int32)') 
def fABATECOST(iYGROSS,iMIU,icost1,index):
    return iYGROSS[index] * icost1[index] * iMIU[index]**expcost2

#Marginal Abatement cost
@njit('float64(float64[:],int32)')
def fMCABATE(iMIU,index):
    return pbacktime[index] * iMIU[index]**(expcost2-1)

#Price of carbon reduction
@njit('float64(float64[:],int32)')
def fCPRICE(iMIU,index):
    return pbacktime[index] * (iMIU[index])**(expcost2-1)

#Eq. 19: Dynamics of the carbon concentration in the atmosphere
@njit('float64(float64[:],float64[:],float64[:],int32)') 
def fMAT(iMAT,iMU,iE,index):
    if(index == 0):
        return mat0
    else:
        return iMAT[index-1]*b11 + iMU[index-1]*b21 + iE[index-1] * 5 / 3.666

#Eq. 21: Dynamics of the carbon concentration in the ocean LOW level
@njit('float64(float64[:],float64[:],int32)') 
def fML(iML,iMU,index):
    if(index == 0):
        return ml0
    else:
        return iML[index-1] * b33  + iMU[index-1] * b23

#Eq. 20: Dynamics of the carbon concentration in the ocean UP level
@njit('float64(float64[:],float64[:],float64[:],int32)') 
def fMU(iMAT,iMU,iML,index):
    if(index == 0):
        return mu0
    else:
        return iMAT[index-1]*b12 + iMU[index-1]*b22 + iML[index-1]*b32

#Eq. 23: Dynamics of the atmospheric temperature
@njit('float64(float64[:],float64[:],float64[:],int32)') 
def fTATM(iTATM,iFORC,iTOCEAN,index):
    if(index == 0):
        return tatm0
    else:
        return iTATM[index-1] + c1 * (iFORC[index] - (fco22x/t2xco2) * iTATM[index-1] - c3 * (iTATM[index-1] - iTOCEAN[index-1]))

#Eq. 24: Dynamics of the ocean temperature
@njit('float64(float64[:],float64[:],int32)')
def fTOCEAN(iTATM,iTOCEAN,index):
    if(index == 0):
        return tocean0
    else:
        return iTOCEAN[index-1] + c4 * (iTATM[index-1] - iTOCEAN[index-1])

"""
Second: Function related to economic variables
"""

#The total production without climate losses denoted previously by YGROSS
@njit('float64(float64[:],float64[:],float64[:],int32)')
def fYGROSS(ial,il,iK,index):
    return ial[index] * ((il[index]/1000)**(1-gama)) * iK[index]**gama

#The production under the climate damages cost
@njit('float64(float64[:],float64[:],int32)')
def fYNET(iYGROSS, iDAMFRAC, index):
    return iYGROSS[index] * (1 - iDAMFRAC[index])

#Production after abatement cost
@njit('float64(float64[:],float64[:],int32)')
def fY(iYNET,iABATECOST,index):
    return iYNET[index] - iABATECOST[index]

#Consumption Eq. 11
@njit('float64(float64[:],float64[:],int32)')
def fC(iY,iI,index):
    return iY[index] - iI[index]

#Per capita consumption, Eq. 12
@njit('float64(float64[:],float64[:],int32)')
def fCPC(iC,il,index):
    return 1000 * iC[index] / il[index]

#Saving policy: investment
@njit('float64(float64[:],float64[:],int32)')
def fI(iS,iY,index):
    return iS[index] * iY[index] 

#Capital dynamics Eq. 13
@njit('float64(float64[:],float64[:],int32)')
def fK(iK,iI,index):
    if(index == 0):
        return k0
    else:
        return (1-dk)**tstep * iK[index-1] + tstep * iI[index-1]

#Interest rate equation; Eq. 26 added in personal notes
@njit('float64(float64[:],int32)')
def fRI(iCPC,index):
    return (1 + prstp) * (iCPC[index+1]/iCPC[index])**(elasmu/tstep) - 1

#Periodic utility: A form of Eq. 2
@njit('float64(float64[:],float64[:],int32)')
def fCEMUTOTPER(iPERIODU,il,index):
    return iPERIODU[index] * il[index] * rr[index]

#The term between brackets in Eq. 2
@njit('float64(float64[:],float64[:],int32)')
def fPERIODU(iC,il,index):
    return ((iC[index]*1000/il[index])**(1-elasmu) - 1) / (1 - elasmu) - 1

#utility function
@guvectorize([(float64[:], float64[:])], '(n), (m)')
def fUTILITY(iCEMUTOTPER, resUtility):
    resUtility[0] = tstep * scale1 * np.sum(iCEMUTOTPER) + scale2

# %%
"""
In this part we implement the objective function
"""

# * Control rate limits
MIU_lo = np.full(NT,0.01)
MIU_up = np.full(NT,limmiu)
MIU_up[0:29] = 1
MIU_lo[0] = miu0
MIU_up[0] = miu0
MIU_lo[MIU_lo==MIU_up] = 0.99999*MIU_lo[MIU_lo==MIU_up]
bnds1=[]
for i in range(NT):
    bnds1.append((MIU_lo[i],MIU_up[i]))
# * Control variables
lag10 = t > NT - 10
S_lo = np.full(NT,1e-1)
S_lo[lag10] = optlrsav
S_up = np.full(NT,0.9)
S_up[lag10] = optlrsav
S_lo[S_lo==S_up] = 0.99999*S_lo[S_lo==S_up]
bnds2=[]
for i in range(NT):
    bnds2.append((S_lo[i],S_up[i]))
    
# Arbitrary starting values for the control variables:
S_start = np.full(NT,0.2)
S_start[S_start < S_lo] = S_lo[S_start < S_lo]
S_start[S_start > S_up] = S_lo[S_start > S_up]
MIU_start = 0.99*MIU_up
MIU_start[MIU_start < MIU_lo] = MIU_lo[MIU_start < MIU_lo]
MIU_start[MIU_start > MIU_up] = MIU_up[MIU_start > MIU_up]

K = np.zeros(NT)
YGROSS = np.zeros(NT)
EIND = np.zeros(NT)
E = np.zeros(NT)
CCA = np.zeros(NT)
CCATOT = np.zeros(NT)
MAT = np.zeros(NT)
ML = np.zeros(NT)
MU = np.zeros(NT)
FORC = np.zeros(NT)
TATM = np.zeros(NT)
TOCEAN = np.zeros(NT)
DAMFRAC = np.zeros(NT)
DAMAGES = np.zeros(NT)
ABATECOST = np.zeros(NT)
MCABATE = np.zeros(NT)
CPRICE = np.zeros(NT)
YNET = np.zeros(NT)
Y = np.zeros(NT)
I = np.zeros(NT)
C = np.zeros(NT)
CPC = np.zeros(NT)
RI = np.zeros(NT)
PERIODU = np.zeros(NT)
CEMUTOTPER = np.zeros(NT)

# %%
#The objective function
#It returns the utility as scalar
def fOBJ(x,sign,iI,iK,ial,il,iYGROSS,isigma,iEIND,iE,iCCA,iCCATOT,icumetree,iMAT,iMU,iML,iFORC,iTATM,iTOCEAN,iDAMFRAC,iDAMAGES,iABATECOST,icost1,iMCABATE,
         iCPRICE,iYNET,iY,iC,iCPC,iPERIODU,iCEMUTOTPER,iRI,iNT):
    
    iMIU = x[0:iNT]
    iS = x[iNT:(2*iNT)]
    
    for i in range(iNT):
        iK[i] = fK(iK,iI,i)
        iYGROSS[i] = fYGROSS(ial,il,iK,i)
        iEIND[i] = fEIND(iYGROSS, iMIU, isigma,i)
        iE[i] = fE(iEIND,i)
        iCCA[i] = fCCA(iCCA,iEIND,i)
        iCCATOT[i] = fCCATOT(iCCA,icumetree,i)
        iMAT[i] = fMAT(iMAT,iMU,iE,i)
        iML[i] = fML(iML,iMU,i)
        iMU[i] = fMU(iMAT,iMU,iML,i)
        iFORC[i] = fFORC(iMAT,i)
        iTATM[i] = fTATM(iTATM,iFORC,iTOCEAN,i)
        iTOCEAN[i] = fTOCEAN(iTATM,iTOCEAN,i)
        iDAMFRAC[i] = fDAMFRAC(iTATM,i)
        iDAMAGES[i] = fDAMAGES(iYGROSS,iDAMFRAC,i)
        iABATECOST[i] = fABATECOST(iYGROSS,iMIU,icost1,i)
        iMCABATE[i] = fMCABATE(iMIU,i)
        iCPRICE[i] = fCPRICE(iMIU,i)
        iYNET[i] = fYNET(iYGROSS, iDAMFRAC, i)
        iY[i] = fY(iYNET,iABATECOST,i)
        iI[i] = fI(iS,iY,i)
        iC[i] = fC(iY,iI,i)
        iCPC[i] = fCPC(iC,il,i)
        iPERIODU[i] = fPERIODU(iC,il,i)
        iCEMUTOTPER[i] = fCEMUTOTPER(iPERIODU,il,i)
        iRI = fRI(iCPC,i)
        
    resUtility = np.zeros(1)
    fUTILITY(iCEMUTOTPER, resUtility)
    
    return sign*resUtility[0]

# %%
InitializeLabor(l,NT)
InitializeTFP(al,NT)
InitializeGrowthSigma(gsig,NT)
InitializeSigma(sigma,gsig,cost1,NT)
InitializeCarbonTree(cumetree,NT)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_probability as tfp
tfd = tfp.distributions

# Configuration parameters for the whole setup
gamma = 0.99  # Discount factor for past rewards
max_steps_per_episode = 10000
eps = np.finfo(np.float32).eps.item()  # Smallest number such that 1.0 + eps != 1.0

# %%
class OPTIM(object):
    def __init__(self):
        super(OPTIM, self).__init__()
    
    def step(self, action):
        global x, x1, x2
        
        miu = action[0]
        s = action[1]
        x1 = np.append(x1, miu)
        x2 = np.append(x2, s)
        x = np.concatenate([x1,x2])
        obs_ = np.array([miu,s])
        #obs_ = np.array([miu,s,steps+1])
        
        reward = fOBJ(x,1,I,K,al,l,YGROSS,sigma,EIND,E,CCA,CCATOT,cumetree,MAT,MU,ML,FORC,TATM,TOCEAN,DAMFRAC,DAMAGES,ABATECOST,cost1,MCABATE,
         CPRICE,YNET,Y,C,CPC,PERIODU,CEMUTOTPER,RI,steps+1)
        #if reward == np.nan:
            #reward = 0
            
        done = bool(steps==99)
        #if done == True:
            #if reward > 4500:
             #   R = 2
            #else:
            #    R = 1
        #else:
            #R = 0
        return obs_, reward, done
        
    def reset(self):
        return np.array([MIU_start[0],S_start[0]])
        #return np.array([MIU_start[0],S_start[0],0])

# %%
env = OPTIM()
num_inputs = 2
num_hidden = 512

# %%
inputs = layers.Input(shape=(num_inputs,))
common = layers.Dense(num_hidden, activation="relu")(inputs)

#4 for 2 miu and 2 sigmas 
norm_par = layers.Dense(4)(common)

critic = layers.Dense(1)(common)

model = keras.Model(inputs=inputs, outputs=[norm_par, critic])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=100,
    decay_rate=0.8)
optimizer = keras.optimizers.Adam(learning_rate=lr_schedule)
huber_loss = keras.losses.Huber()
action_probs_history = []
critic_value_history = []
rewards_history = []
running_reward = 0
episode_count = 0
Reward = []
epi = []


while True:  # Run until solved
    state = env.reset()
    episode_reward = 0
    x1 = []
    x2 = []
    
    with tf.GradientTape() as tape:
        steps = 0
        for timestep in range(1, max_steps_per_episode):
            x = []

            state = tf.convert_to_tensor(state)
            state = tf.expand_dims(state, 0)

            # Predict action probabilities and estimated future rewards
            # from environment state
            norm_par, critic_value = model(state)
            norm_dist = tfd.MultivariateNormalDiag(loc=[norm_par[0, 0], norm_par[0, 1]], 
                                                   scale_diag=[tf.nn.softplus(norm_par[0, 2])+0.1, 
                                                               tf.nn.softplus(norm_par[0, 3])+0.1])
            
            # Sample action from action probability distribution
            action = tf.squeeze(norm_dist.sample(1), axis=0)
            action = tf.clip_by_value(tf.expand_dims(action, 1), tf.constant([MIU_lo[steps], S_lo[steps]], shape = [2,1], dtype=tf.float32),
                                      tf.constant([MIU_up[steps], S_up[steps]], shape = [2,1], dtype=tf.float32))
            tflog = tf.math.log(norm_dist.prob(tf.squeeze(action))+1)
            critic_value_history.append(critic_value[0, 0])
            action_probs_history.append(tflog)

            # Apply the sampled action in our environment
            state, reward, done = env.step(action)
            rewards_history.append(reward)
            episode_reward += reward
            
            #print(norm_par, action, reward)
            steps += 1
            
            if done:
                break

        # Update running reward to check condition for solving
        running_reward = 0.05 * episode_reward + (1 - 0.05) * running_reward

        # Calculate expected value from rewards
        # - At each timestep what was the total reward received after that timestep
        # - Rewards in the past are discounted by multiplying them with gamma
        # - These are the labels for our critic
        returns = []
        discounted_sum = 0
        for r in rewards_history[::-1]:
            discounted_sum = r + gamma * discounted_sum
            returns.insert(0, discounted_sum)

        # Normalize
        returns = np.array(returns)
        returns = (returns - np.mean(returns)) / (np.std(returns) + eps)
        returns = returns.tolist()

        # Calculating loss values to update our network
        history = zip(action_probs_history, critic_value_history, returns)
        actor_losses = []
        critic_losses = []
        for log_prob, value, ret in history:
            diff = ret - value
            actor_losses.append(-log_prob * diff)  # actor loss

            # The critic must be updated so that it predicts a better estimate of
            # the future rewards.
            critic_losses.append(
                huber_loss(tf.expand_dims(value, 0), tf.expand_dims(ret, 0))
            )

        # Backpropagation
        loss_value = sum(actor_losses) + sum(critic_losses)
        
        grads = tape.gradient(loss_value, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))

        # Clear the loss and reward history
        action_probs_history.clear()
        critic_value_history.clear()
        rewards_history.clear()

    # Log details
    episode_count += 1
    template = "running reward: {:.2f}, reward: {:.2f} at episode {}"
    print(template.format(running_reward, reward, episode_count))
    
    Reward.append(reward)
    epi.append(episode_count)
    
    if reward > 4500:  # Condition to consider the task solved
        print("Solved at episode {}!".format(episode_count))
        break
        
    if episode_count == 1000:  
        print("Reached episode {}!".format(episode_count))
        break
# Out:
# running reward: 1889.00, reward: 2897.83 at episode 1
# running reward: 12495.86, reward: 2058.99 at episode 2
# running reward: 18773.21, reward: 1366.60 at episode 3
# running reward: 30301.29, reward: 2557.76 at episode 4
# running reward: 35765.97, reward: 1267.07 at episode 5
# running reward: 52814.63, reward: 3944.92 at episode 6
# running reward: 57325.19, reward: 1300.49 at episode 7
# running reward: 67826.45, reward: 2630.94 at episode 8
# running reward: 79016.57, reward: 2975.12 at episode 9
# running reward: 88698.85, reward: 2786.55 at episode 10
# running reward: 102723.10, reward: 3744.30 at episode 11
# running reward: 111721.25, reward: 2830.63 at episode 12
# running reward: 124061.88, reward: 3554.52 at episode 13
# running reward: 128541.80, reward: 2073.11 at episode 14
# running reward: 139060.03, reward: 3394.11 at episode 15
# running reward: 128927.85, reward: -725.38 at episode 16
# running reward: 129987.29, reward: 1541.69 at episode 17
# running reward: 141668.89, reward: 3783.49 at episode 18
# running reward: 143880.96, reward: 1683.87 at episode 19
# running reward: 150874.50, reward: 2898.91 at episode 20
# running reward: 159882.08, reward: 3339.80 at episode 21
# running reward: 161660.08, reward: 1910.13 at episode 22
# running reward: 161642.31, reward: 1598.89 at episode 23
# running reward: 165597.63, reward: 2433.22 at episode 24
# running reward: 172304.12, reward: 3067.33 at episode 25
# running reward: 175840.35, reward: 2400.58 at episode 26
# running reward: 175101.57, reward: 1599.37 at episode 27
# running reward: 175208.00, reward: 1813.01 at episode 28
# running reward: 179674.91, reward: 2596.40 at episode 29
# running reward: 181694.54, reward: 2101.64 at episode 30
# running reward: 186499.49, reward: 2939.85 at episode 31
# running reward: 187355.98, reward: 1987.51 at episode 32
# running reward: 191776.44, reward: 2809.42 at episode 33
# running reward: 196418.53, reward: 2846.50 at episode 34
# running reward: 199772.51, reward: 2628.86 at episode 35
# running reward: 203654.83, reward: 2760.17 at episode 36
# running reward: 204359.33, reward: 2162.10 at episode 37
# running reward: 211378.41, reward: 3487.26 at episode 38
# running reward: 219943.64, reward: 3837.47 at episode 39
# running reward: 228829.74, reward: 4011.34 at episode 40
# running reward: 236166.87, reward: 3744.49 at episode 41
# running reward: 243555.15, reward: 3836.36 at episode 42
# running reward: 243677.21, reward: 2389.98 at episode 43
# running reward: 247805.81, reward: 3238.12 at episode 44
# running reward: 254523.49, reward: 3912.63 at episode 45
# running reward: 259147.55, reward: 3416.96 at episode 46
# running reward: 263544.42, reward: 3470.66 at episode 47
# running reward: 267451.60, reward: 3486.00 at episode 48
# running reward: 271202.08, reward: 3385.00 at episode 49
# running reward: 273803.14, reward: 3234.74 at episode 50
# running reward: 274752.64, reward: 2900.93 at episode 51
# running reward: 280398.64, reward: 3961.51 at episode 52
# running reward: 286677.71, reward: 4047.20 at episode 53
# running reward: 291005.57, reward: 3729.09 at episode 54
# running reward: 295210.95, reward: 3713.94 at episode 55
# running reward: 300314.92, reward: 4009.41 at episode 56
# running reward: 305673.18, reward: 4102.69 at episode 57
# running reward: 310922.70, reward: 4093.86 at episode 58
# running reward: 316045.78, reward: 4128.03 at episode 59
# running reward: 321199.37, reward: 4199.86 at episode 60
# running reward: 324839.31, reward: 3956.13 at episode 61
# running reward: 329276.65, reward: 4126.43 at episode 62
# running reward: 333929.50, reward: 4223.82 at episode 63
# running reward: 338315.22, reward: 4212.96 at episode 64
# running reward: 339359.80, reward: 3569.95 at episode 65
# running reward: 343286.49, reward: 4195.09 at episode 66
# running reward: 347147.82, reward: 4216.27 at episode 67
# running reward: 350623.74, reward: 4163.07 at episode 68
# running reward: 354050.08, reward: 4194.04 at episode 69
# running reward: 357123.36, reward: 4154.55 at episode 70
# running reward: 360353.50, reward: 4215.55 at episode 71
# running reward: 363254.82, reward: 4186.09 at episode 72
# running reward: 366329.49, reward: 4250.92 at episode 73
# running reward: 369019.53, reward: 4190.30 at episode 74
# running reward: 371882.14, reward: 4279.94 at episode 75
# running reward: 374031.94, reward: 4129.66 at episode 76
# running reward: 376127.84, reward: 4160.00 at episode 77
# running reward: 378477.08, reward: 4242.31 at episode 78
# running reward: 380335.28, reward: 4152.52 at episode 79
# running reward: 382356.42, reward: 4200.37 at episode 80
# running reward: 384284.78, reward: 4214.30 at episode 81
# running reward: 386650.41, reward: 4332.40 at episode 82
# running reward: 388527.83, reward: 4226.89 at episode 83
# running reward: 390084.28, reward: 4197.26 at episode 84
# running reward: 391179.69, reward: 4131.10 at episode 85
# running reward: 392683.39, reward: 4196.91 at episode 86
# running reward: 394600.90, reward: 4325.02 at episode 87
# running reward: 396563.49, reward: 4345.34 at episode 88
# running reward: 398176.09, reward: 4277.25 at episode 89
# running reward: 399582.97, reward: 4264.81 at episode 90
# running reward: 400446.56, reward: 4154.40 at episode 91
# running reward: 401263.93, reward: 4170.46 at episode 92
# running reward: 402000.49, reward: 4159.55 at episode 93
# running reward: 403221.56, reward: 4272.29 at episode 94
# running reward: 404114.80, reward: 4200.02 at episode 95
# running reward: 404589.10, reward: 4131.48 at episode 96
# running reward: 405192.44, reward: 4173.72 at episode 97
# running reward: 406233.06, reward: 4263.94 at episode 98
# running reward: 407202.79, reward: 4267.12 at episode 99
# running reward: 407800.00, reward: 4177.99 at episode 100
# running reward: 408301.05, reward: 4173.12 at episode 101
# running reward: 409272.11, reward: 4293.52 at episode 102
# running reward: 409951.96, reward: 4218.62 at episode 103
# running reward: 410349.76, reward: 4180.08 at episode 104
# running reward: 411131.15, reward: 4268.92 at episode 105
# running reward: 411458.29, reward: 4158.73 at episode 106
# running reward: 412133.75, reward: 4263.80 at episode 107
# running reward: 412244.70, reward: 4124.65 at episode 108
# running reward: 413007.55, reward: 4296.53 at episode 109
# running reward: 413451.50, reward: 4213.57 at episode 110
# running reward: 414087.79, reward: 4267.15 at episode 111
# running reward: 414179.33, reward: 4142.62 at episode 112
# running reward: 414228.92, reward: 4151.97 at episode 113
# running reward: 414689.92, reward: 4247.42 at episode 114
# running reward: 415426.77, reward: 4295.99 at episode 115
# running reward: 415656.21, reward: 4193.27 at episode 116
# running reward: 415977.05, reward: 4217.69 at episode 117
# running reward: 416085.72, reward: 4179.80 at episode 118
# running reward: 416218.80, reward: 4194.37 at episode 119
# running reward: 416480.54, reward: 4215.00 at episode 120
# running reward: 416844.76, reward: 4232.29 at episode 121
# running reward: 417327.78, reward: 4276.34 at episode 122
# running reward: 417465.42, reward: 4184.46 at episode 123
# running reward: 417623.37, reward: 4217.79 at episode 124
# running reward: 418082.55, reward: 4268.84 at episode 125
# running reward: 418087.75, reward: 4170.36 at episode 126
# running reward: 418179.52, reward: 4206.42 at episode 127
# running reward: 418581.40, reward: 4261.34 at episode 128
# running reward: 418646.98, reward: 4193.15 at episode 129
# running reward: 418589.89, reward: 4180.37 at episode 130
# running reward: 418927.98, reward: 4256.38 at episode 131
# running reward: 419205.43, reward: 4244.55 at episode 132
# running reward: 418938.11, reward: 4124.73 at episode 133
# running reward: 418794.53, reward: 4165.17 at episode 134
# running reward: 419041.38, reward: 4247.87 at episode 135
# running reward: 419679.48, reward: 4327.92 at episode 136
# running reward: 419835.59, reward: 4211.69 at episode 137
# running reward: 420028.74, reward: 4240.77 at episode 138
# running reward: 419752.98, reward: 4133.37 at episode 139
# running reward: 420270.21, reward: 4329.09 at episode 140
# running reward: 420646.30, reward: 4267.51 at episode 141
# running reward: 421173.23, reward: 4321.91 at episode 142
# running reward: 421831.62, reward: 4339.10 at episode 143
# running reward: 421851.07, reward: 4205.39 at episode 144
# running reward: 422463.91, reward: 4368.95 at episode 145
# running reward: 422761.98, reward: 4274.40 at episode 146
# running reward: 422712.64, reward: 4207.49 at episode 147
# running reward: 422795.98, reward: 4244.89 at episode 148
# running reward: 422610.62, reward: 4187.81 at episode 149
# running reward: 422927.99, reward: 4293.44 at episode 150
# running reward: 422860.66, reward: 4210.15 at episode 151
# running reward: 423056.72, reward: 4281.05 at episode 152
# running reward: 423302.61, reward: 4266.87 at episode 153
# running reward: 423112.79, reward: 4191.98 at episode 154
# running reward: 423125.94, reward: 4241.29 at episode 155
# running reward: 423323.84, reward: 4280.82 at episode 156
# running reward: 423658.46, reward: 4304.16 at episode 157
# running reward: 423804.69, reward: 4247.02 at episode 158
# running reward: 423399.17, reward: 4152.31 at episode 159
# running reward: 423496.04, reward: 4266.32 at episode 160
# running reward: 423741.98, reward: 4285.59 at episode 161
# running reward: 423841.52, reward: 4251.76 at episode 162
# running reward: 423856.70, reward: 4244.89 at episode 163
# running reward: 423959.39, reward: 4264.45 at episode 164
# running reward: 424041.00, reward: 4252.12 at episode 165
# running reward: 423733.83, reward: 4163.72 at episode 166
# running reward: 424138.77, reward: 4337.28 at episode 167
# running reward: 424937.36, reward: 4418.34 at episode 168
# running reward: 425553.41, reward: 4367.95 at episode 169
# running reward: 425936.48, reward: 4320.06 at episode 170
# running reward: 426060.84, reward: 4284.00 at episode 171
# running reward: 425847.81, reward: 4212.12 at episode 172
# running reward: 425462.36, reward: 4167.24 at episode 173
# running reward: 425166.51, reward: 4197.60 at episode 174
# running reward: 425149.16, reward: 4264.88 at episode 175
# running reward: 424850.26, reward: 4177.39 at episode 176
# running reward: 424841.43, reward: 4246.53 at episode 177
# running reward: 424254.84, reward: 4120.46 at episode 178
# running reward: 424179.94, reward: 4250.92 at episode 179
# running reward: 424115.88, reward: 4218.84 at episode 180
# running reward: 424316.91, reward: 4294.89 at episode 181
# running reward: 424932.23, reward: 4375.53 at episode 182
# running reward: 425433.65, reward: 4345.40 at episode 183
# running reward: 425686.32, reward: 4297.24 at episode 184
# running reward: 425789.53, reward: 4273.24 at episode 185
# running reward: 425431.98, reward: 4176.35 at episode 186
# running reward: 425772.60, reward: 4343.37 at episode 187
# running reward: 425861.67, reward: 4264.04 at episode 188
# running reward: 426041.87, reward: 4301.04 at episode 189
# running reward: 426129.50, reward: 4273.52 at episode 190
# running reward: 426347.32, reward: 4308.08 at episode 191
# running reward: 426226.07, reward: 4227.90 at episode 192
# running reward: 426503.48, reward: 4335.46 at episode 193
# running reward: 426358.17, reward: 4231.84 at episode 194
# running reward: 426906.40, reward: 4385.57 at episode 195
# running reward: 426661.69, reward: 4190.79 at episode 196
# running reward: 426141.67, reward: 4161.74 at episode 197
# running reward: 425884.56, reward: 4213.06 at episode 198
# running reward: 425707.37, reward: 4230.62 at episode 199
# running reward: 425902.64, reward: 4307.77 at episode 200
# running reward: 426051.11, reward: 4282.54 at episode 201
# running reward: 425982.54, reward: 4249.22 at episode 202
# running reward: 426155.72, reward: 4284.18 at episode 203
# running reward: 425936.20, reward: 4215.80 at episode 204
# running reward: 425393.30, reward: 4138.22 at episode 205
# running reward: 425677.51, reward: 4334.36 at episode 206
# running reward: 426011.03, reward: 4329.03 at episode 207
# running reward: 426157.69, reward: 4283.73 at episode 208
# running reward: 425643.81, reward: 4142.07 at episode 209
# running reward: 425976.90, reward: 4345.60 at episode 210
# running reward: 426080.66, reward: 4271.63 at episode 211
# running reward: 426072.91, reward: 4255.85 at episode 212
# running reward: 425291.66, reward: 4086.82 at episode 213
# running reward: 425249.84, reward: 4257.60 at episode 214
# running reward: 425350.29, reward: 4287.43 at episode 215
# running reward: 425696.79, reward: 4324.19 at episode 216
# running reward: 425833.50, reward: 4278.17 at episode 217
# running reward: 425833.78, reward: 4251.98 at episode 218
# running reward: 425965.20, reward: 4286.59 at episode 219
# running reward: 426448.15, reward: 4371.19 at episode 220
# running reward: 426383.58, reward: 4236.18 at episode 221
# running reward: 426855.44, reward: 4375.41 at episode 222
# running reward: 426870.34, reward: 4255.17 at episode 223
# running reward: 426475.56, reward: 4178.37 at episode 224
# running reward: 426523.61, reward: 4287.53 at episode 225
# running reward: 426669.80, reward: 4302.36 at episode 226
# running reward: 427179.27, reward: 4384.68 at episode 227
# running reward: 427365.40, reward: 4283.31 at episode 228
# running reward: 427093.32, reward: 4213.31 at episode 229
# running reward: 426281.84, reward: 4095.62 at episode 230
# running reward: 426318.63, reward: 4292.03 at episode 231
# running reward: 426468.29, reward: 4295.96 at episode 232
# running reward: 426323.65, reward: 4226.06 at episode 233
# running reward: 426695.99, reward: 4356.47 at episode 234
# running reward: 427034.61, reward: 4323.01 at episode 235
# running reward: 427281.53, reward: 4320.50 at episode 236
# running reward: 427641.84, reward: 4360.56 at episode 237
# running reward: 427841.31, reward: 4305.44 at episode 238
# running reward: 427749.28, reward: 4248.79 at episode 239
# running reward: 427408.62, reward: 4206.43 at episode 240
# running reward: 426826.14, reward: 4146.39 at episode 241
# running reward: 427022.24, reward: 4342.13 at episode 242
# running reward: 426918.85, reward: 4231.65 at episode 243
# running reward: 427167.93, reward: 4340.69 at episode 244
# running reward: 427060.05, reward: 4221.16 at episode 245
# running reward: 427117.48, reward: 4294.02 at episode 246
# running reward: 427290.29, reward: 4303.38 at episode 247
# running reward: 427561.85, reward: 4331.44 at episode 248
# running reward: 427605.80, reward: 4284.41 at episode 249
# running reward: 427775.26, reward: 4309.84 at episode 250
# running reward: 427566.02, reward: 4223.76 at episode 251
# running reward: 427663.52, reward: 4308.71 at episode 252
# running reward: 427423.41, reward: 4213.41 at episode 253
# running reward: 427341.51, reward: 4265.78 at episode 254
# running reward: 427605.55, reward: 4343.85 at episode 255
# running reward: 427427.94, reward: 4211.55 at episode 256
# running reward: 427711.92, reward: 4358.49 at episode 257
# running reward: 427849.48, reward: 4288.43 at episode 258
# running reward: 427444.02, reward: 4185.21 at episode 259
# running reward: 427272.45, reward: 4249.56 at episode 260
# running reward: 427527.04, reward: 4327.62 at episode 261
# running reward: 427712.59, reward: 4308.54 at episode 262
# running reward: 427340.64, reward: 4196.16 at episode 263
# running reward: 426555.99, reward: 4105.00 at episode 264
# running reward: 425948.29, reward: 4155.13 at episode 265
# running reward: 425708.07, reward: 4211.18 at episode 266
# running reward: 425367.25, reward: 4189.38 at episode 267
# running reward: 425360.61, reward: 4265.83 at episode 268
# running reward: 425321.43, reward: 4232.79 at episode 269
# running reward: 424847.17, reward: 4155.36 at episode 270
# running reward: 424314.49, reward: 4142.33 at episode 271
# running reward: 424668.22, reward: 4335.91 at episode 272
# running reward: 424768.96, reward: 4249.73 at episode 273
# running reward: 424929.60, reward: 4282.77 at episode 274
# running reward: 424441.95, reward: 4135.23 at episode 275
# running reward: 424822.99, reward: 4359.62 at episode 276
# running reward: 425372.08, reward: 4354.83 at episode 277
# running reward: 425741.84, reward: 4314.11 at episode 278
# running reward: 425874.47, reward: 4278.75 at episode 279
# running reward: 425515.79, reward: 4171.68 at episode 280
# running reward: 425437.61, reward: 4257.54 at episode 281
# running reward: 425951.14, reward: 4372.32 at episode 282
# running reward: 426354.12, reward: 4347.88 at episode 283
# running reward: 426770.69, reward: 4343.57 at episode 284
# running reward: 426956.81, reward: 4292.86 at episode 285
# running reward: 427263.69, reward: 4338.45 at episode 286
# running reward: 426877.63, reward: 4170.46 at episode 287
# running reward: 426334.47, reward: 4156.39 at episode 288
# running reward: 426424.34, reward: 4300.73 at episode 289
# running reward: 426517.79, reward: 4299.35 at episode 290
# running reward: 426924.60, reward: 4345.44 at episode 291
# running reward: 427272.75, reward: 4332.49 at episode 292
# running reward: 427496.62, reward: 4306.68 at episode 293
# running reward: 427208.19, reward: 4205.29 at episode 294
# running reward: 426458.68, reward: 4109.00 at episode 295
# running reward: 425998.45, reward: 4187.52 at episode 296
# running reward: 426087.53, reward: 4287.25 at episode 297
# running reward: 425624.54, reward: 4164.80 at episode 298
# running reward: 426198.82, reward: 4399.43 at episode 299
# running reward: 426804.61, reward: 4364.95 at episode 300
# running reward: 426907.86, reward: 4280.89 at episode 301
# running reward: 426757.26, reward: 4227.42 at episode 302
# running reward: 427128.61, reward: 4371.58 at episode 303
# running reward: 426724.36, reward: 4150.42 at episode 304
# running reward: 426513.03, reward: 4248.27 at episode 305
# running reward: 426726.38, reward: 4311.61 at episode 306
# running reward: 427102.71, reward: 4347.89 at episode 307
# running reward: 427398.57, reward: 4325.40 at episode 308
# running reward: 427588.75, reward: 4318.60 at episode 309
# running reward: 427130.91, reward: 4150.45 at episode 310
# running reward: 427124.29, reward: 4287.29 at episode 311
# running reward: 426694.57, reward: 4175.21 at episode 312
# running reward: 426957.28, reward: 4353.55 at episode 313
# running reward: 427106.43, reward: 4280.69 at episode 314
# running reward: 427322.98, reward: 4315.65 at episode 315
# running reward: 427350.22, reward: 4277.67 at episode 316
# running reward: 427155.44, reward: 4228.89 at episode 317
# running reward: 426542.33, reward: 4136.09 at episode 318
# running reward: 425893.04, reward: 4150.67 at episode 319
# running reward: 426140.52, reward: 4319.37 at episode 320
# running reward: 426254.66, reward: 4275.01 at episode 321
# running reward: 426199.58, reward: 4246.16 at episode 322
# running reward: 425727.17, reward: 4154.47 at episode 323
# running reward: 425865.83, reward: 4309.00 at episode 324
# running reward: 426158.80, reward: 4320.30 at episode 325
# running reward: 426670.41, reward: 4374.19 at episode 326
# running reward: 427000.16, reward: 4320.20 at episode 327
# running reward: 426492.40, reward: 4138.43 at episode 328
# running reward: 425726.61, reward: 4115.31 at episode 329
# running reward: 425287.32, reward: 4176.03 at episode 330
# running reward: 425384.58, reward: 4290.92 at episode 331
# running reward: 425684.60, reward: 4321.73 at episode 332
# running reward: 425811.87, reward: 4267.32 at episode 333
# running reward: 425772.12, reward: 4249.09 at episode 334
# running reward: 425443.90, reward: 4185.89 at episode 335
# running reward: 425202.24, reward: 4199.68 at episode 336
# running reward: 425368.05, reward: 4317.49 at episode 337
# running reward: 425890.69, reward: 4359.43 at episode 338
# running reward: 426159.57, reward: 4293.04 at episode 339
# running reward: 425698.46, reward: 4151.55 at episode 340
# running reward: 425336.83, reward: 4196.97 at episode 341
# running reward: 425036.76, reward: 4195.79 at episode 342
# running reward: 424587.82, reward: 4155.91 at episode 343
# running reward: 424291.78, reward: 4183.96 at episode 344
# running reward: 424281.94, reward: 4248.30 at episode 345
# running reward: 423900.30, reward: 4154.34 at episode 346
# running reward: 423537.44, reward: 4169.21 at episode 347
# running reward: 423395.93, reward: 4212.91 at episode 348
# running reward: 423757.75, reward: 4329.53 at episode 349
# running reward: 424230.21, reward: 4319.51 at episode 350
# running reward: 423770.15, reward: 4127.33 at episode 351
# running reward: 423822.04, reward: 4266.28 at episode 352
# running reward: 424277.57, reward: 4342.10 at episode 353
# running reward: 424734.99, reward: 4330.46 at episode 354
# running reward: 424286.43, reward: 4133.38 at episode 355
# running reward: 424458.29, reward: 4301.85 at episode 356
# running reward: 424890.79, reward: 4330.71 at episode 357
# running reward: 424678.24, reward: 4186.21 at episode 358
# running reward: 425071.49, reward: 4366.31 at episode 359
# running reward: 425564.39, reward: 4337.17 at episode 360
# running reward: 425699.82, reward: 4264.93 at episode 361
# running reward: 425120.68, reward: 4131.87 at episode 362
# running reward: 424882.99, reward: 4208.57 at episode 363
# running reward: 424829.77, reward: 4235.96 at episode 364
# running reward: 425160.80, reward: 4321.48 at episode 365
# running reward: 425467.82, reward: 4323.53 at episode 366
# running reward: 425670.17, reward: 4285.02 at episode 367
# running reward: 425963.23, reward: 4323.84 at episode 368
# running reward: 426113.75, reward: 4287.72 at episode 369
# running reward: 425621.64, reward: 4144.56 at episode 370
# running reward: 425155.37, reward: 4155.44 at episode 371
# running reward: 424116.02, reward: 4034.01 at episode 372
# running reward: 423903.60, reward: 4231.53 at episode 373
# running reward: 424246.70, reward: 4314.33 at episode 374
# running reward: 424261.49, reward: 4232.98 at episode 375
# running reward: 424040.82, reward: 4188.29 at episode 376
# running reward: 424212.66, reward: 4293.85 at episode 377
# running reward: 424412.38, reward: 4272.46 at episode 378
# running reward: 424029.80, reward: 4153.82 at episode 379
# running reward: 424153.66, reward: 4292.40 at episode 380
# running reward: 424258.67, reward: 4263.24 at episode 381
# running reward: 424560.19, reward: 4299.15 at episode 382
# running reward: 424104.88, reward: 4127.17 at episode 383
# running reward: 423668.30, reward: 4159.81 at episode 384
# running reward: 423633.76, reward: 4241.30 at episode 385
# running reward: 423405.63, reward: 4193.42 at episode 386
# running reward: 423815.34, reward: 4316.88 at episode 387
# running reward: 424014.61, reward: 4281.96 at episode 388
# running reward: 424065.58, reward: 4238.82 at episode 389
# running reward: 423608.27, reward: 4133.50 at episode 390
# running reward: 423713.27, reward: 4284.16 at episode 391
# running reward: 423628.47, reward: 4214.75 at episode 392
# running reward: 424286.16, reward: 4377.00 at episode 393
# running reward: 423621.49, reward: 4077.02 at episode 394
# running reward: 423753.84, reward: 4281.90 at episode 395
# running reward: 423998.86, reward: 4294.21 at episode 396
# running reward: 424397.48, reward: 4326.13 at episode 397
# running reward: 424235.04, reward: 4194.67 at episode 398
# running reward: 424443.71, reward: 4304.27 at episode 399
# running reward: 424447.55, reward: 4232.26 at episode 400
# running reward: 424671.84, reward: 4291.83 at episode 401
# running reward: 424807.24, reward: 4267.23 at episode 402
# running reward: 425171.01, reward: 4332.47 at episode 403
# running reward: 425336.62, reward: 4281.90 at episode 404
# running reward: 425886.60, reward: 4375.23 at episode 405
# running reward: 426130.82, reward: 4303.99 at episode 406
# running reward: 425989.36, reward: 4219.18 at episode 407
# running reward: 426314.73, reward: 4337.82 at episode 408
# running reward: 426207.59, reward: 4217.61 at episode 409
# running reward: 425825.62, reward: 4186.67 at episode 410
# running reward: 425748.54, reward: 4250.79 at episode 411
# running reward: 425527.94, reward: 4210.94 at episode 412
# running reward: 425278.67, reward: 4215.26 at episode 413
# running reward: 424975.79, reward: 4179.82 at episode 414
# running reward: 424613.37, reward: 4175.57 at episode 415
# running reward: 424549.26, reward: 4242.72 at episode 416
# running reward: 423956.60, reward: 4116.85 at episode 417
# running reward: 424147.41, reward: 4293.13 at episode 418
# running reward: 424569.33, reward: 4334.28 at episode 419
# running reward: 424651.84, reward: 4247.83 at episode 420
# running reward: 424227.09, reward: 4150.08 at episode 421
# running reward: 424396.45, reward: 4295.75 at episode 422
# running reward: 423744.15, reward: 4082.30 at episode 423
# running reward: 423835.13, reward: 4279.71 at episode 424
# running reward: 424077.52, reward: 4285.55 at episode 425
# running reward: 424300.43, reward: 4291.81 at episode 426
# running reward: 424530.78, reward: 4290.40 at episode 427
# running reward: 424356.99, reward: 4216.02 at episode 428
# running reward: 424212.38, reward: 4198.37 at episode 429
# running reward: 424067.37, reward: 4211.16 at episode 430
# running reward: 424404.52, reward: 4323.30 at episode 431
# running reward: 424973.42, reward: 4372.48 at episode 432
# running reward: 425451.84, reward: 4336.87 at episode 433
# running reward: 425559.18, reward: 4264.01 at episode 434
# running reward: 425503.71, reward: 4242.23 at episode 435
# running reward: 425059.56, reward: 4148.38 at episode 436
# running reward: 425005.27, reward: 4257.88 at episode 437
# running reward: 425063.37, reward: 4261.09 at episode 438
# running reward: 424871.91, reward: 4202.70 at episode 439
# running reward: 424783.20, reward: 4236.86 at episode 440
# running reward: 424585.56, reward: 4203.25 at episode 441
# running reward: 424441.68, reward: 4217.85 at episode 442
# running reward: 424778.84, reward: 4320.39 at episode 443
# running reward: 425301.73, reward: 4375.77 at episode 444
# running reward: 425678.27, reward: 4321.23 at episode 445
# running reward: 425769.28, reward: 4274.60 at episode 446
# running reward: 425844.48, reward: 4255.21 at episode 447
# running reward: 425629.69, reward: 4215.26 at episode 448
# running reward: 425216.28, reward: 4155.74 at episode 449
# running reward: 425051.29, reward: 4235.26 at episode 450
# running reward: 425272.58, reward: 4311.06 at episode 451
# running reward: 425681.34, reward: 4333.72 at episode 452
# running reward: 426244.97, reward: 4377.66 at episode 453
# running reward: 426844.02, reward: 4378.97 at episode 454
# running reward: 427114.53, reward: 4328.94 at episode 455
# running reward: 426925.70, reward: 4206.11 at episode 456
# running reward: 427148.92, reward: 4321.18 at episode 457
# running reward: 426861.90, reward: 4195.87 at episode 458
# running reward: 425946.52, reward: 4078.62 at episode 459
# running reward: 426160.28, reward: 4328.75 at episode 460
# running reward: 426498.99, reward: 4332.35 at episode 461
# running reward: 427047.70, reward: 4382.29 at episode 462
# running reward: 426636.47, reward: 4160.00 at episode 463
# running reward: 426450.70, reward: 4238.64 at episode 464
# running reward: 425866.30, reward: 4138.47 at episode 465
# running reward: 425524.06, reward: 4186.32 at episode 466
# running reward: 425442.93, reward: 4257.13 at episode 467
# running reward: 425170.20, reward: 4190.78 at episode 468
# running reward: 425275.54, reward: 4281.56 at episode 469
# running reward: 425066.34, reward: 4202.84 at episode 470
# running reward: 425089.76, reward: 4257.85 at episode 471
# running reward: 425047.72, reward: 4241.67 at episode 472
# running reward: 425374.59, reward: 4332.93 at episode 473
# running reward: 425788.20, reward: 4338.95 at episode 474
# running reward: 425345.09, reward: 4150.15 at episode 475
# running reward: 425010.48, reward: 4180.45 at episode 476
# running reward: 424923.99, reward: 4237.75 at episode 477
# running reward: 425013.13, reward: 4267.12 at episode 478
# running reward: 425016.75, reward: 4248.78 at episode 479
# running reward: 424689.11, reward: 4189.34 at episode 480
# running reward: 424635.96, reward: 4240.97 at episode 481
# running reward: 424832.56, reward: 4293.18 at episode 482
# running reward: 425398.35, reward: 4367.70 at episode 483
# running reward: 424961.68, reward: 4127.05 at episode 484
# running reward: 424364.34, reward: 4139.87 at episode 485
# running reward: 424691.71, reward: 4337.70 at episode 486
# running reward: 424664.33, reward: 4229.96 at episode 487
# running reward: 424685.74, reward: 4250.24 at episode 488
# running reward: 424471.18, reward: 4195.22 at episode 489
# running reward: 424505.74, reward: 4257.94 at episode 490
# running reward: 424593.35, reward: 4257.48 at episode 491
# running reward: 424593.75, reward: 4239.29 at episode 492
# running reward: 424779.23, reward: 4296.00 at episode 493
# running reward: 424827.17, reward: 4261.36 at episode 494
# running reward: 424935.15, reward: 4259.98 at episode 495
# running reward: 425174.75, reward: 4306.56 at episode 496
# running reward: 425368.91, reward: 4292.55 at episode 497
# running reward: 424972.71, reward: 4150.34 at episode 498
# running reward: 424641.44, reward: 4183.45 at episode 499
# running reward: 424890.82, reward: 4324.22 at episode 500
# running reward: 424605.03, reward: 4175.70 at episode 501
# running reward: 424515.74, reward: 4230.54 at episode 502
# running reward: 423841.39, reward: 4092.24 at episode 503
# running reward: 424052.05, reward: 4306.75 at episode 504
# running reward: 424031.22, reward: 4232.07 at episode 505
# running reward: 424274.79, reward: 4291.47 at episode 506
# running reward: 423743.52, reward: 4110.33 at episode 507
# running reward: 423285.30, reward: 4165.76 at episode 508
# running reward: 423339.09, reward: 4239.44 at episode 509
# running reward: 423430.90, reward: 4256.08 at episode 510
# running reward: 423686.50, reward: 4298.08 at episode 511
# running reward: 423850.36, reward: 4265.00 at episode 512
# running reward: 424140.89, reward: 4293.55 at episode 513
# running reward: 424412.62, reward: 4307.46 at episode 514
# running reward: 424192.92, reward: 4185.48 at episode 515
# running reward: 424533.57, reward: 4314.87 at episode 516
# running reward: 424971.83, reward: 4337.96 at episode 517
# running reward: 424680.18, reward: 4173.01 at episode 518
# running reward: 425044.76, reward: 4343.46 at episode 519
# running reward: 424947.28, reward: 4213.08 at episode 520
# running reward: 425211.63, reward: 4315.35 at episode 521
# running reward: 425972.87, reward: 4415.08 at episode 522
# running reward: 426314.21, reward: 4318.35 at episode 523
# running reward: 425902.07, reward: 4153.08 at episode 524
# running reward: 425374.23, reward: 4161.05 at episode 525
# running reward: 425272.85, reward: 4231.39 at episode 526
# running reward: 425456.44, reward: 4308.40 at episode 527
# running reward: 424989.87, reward: 4146.05 at episode 528
# running reward: 424982.78, reward: 4257.71 at episode 529
# running reward: 425091.42, reward: 4272.61 at episode 530
# running reward: 425031.75, reward: 4233.00 at episode 531
# running reward: 425460.41, reward: 4350.76 at episode 532
# running reward: 425135.50, reward: 4170.59 at episode 533
# running reward: 425212.27, reward: 4275.09 at episode 534
# running reward: 425434.77, reward: 4298.03 at episode 535
# running reward: 425497.38, reward: 4266.65 at episode 536
# running reward: 425361.07, reward: 4218.45 at episode 537
# running reward: 425108.70, reward: 4200.41 at episode 538
# running reward: 424960.53, reward: 4236.55 at episode 539
# running reward: 424349.74, reward: 4106.15 at episode 540
# running reward: 424038.11, reward: 4188.05 at episode 541
# running reward: 423889.60, reward: 4215.12 at episode 542
# running reward: 423979.87, reward: 4262.52 at episode 543
# running reward: 424079.59, reward: 4262.04 at episode 544
# running reward: 424469.91, reward: 4337.48 at episode 545
# running reward: 424648.42, reward: 4253.47 at episode 546
# running reward: 424610.25, reward: 4245.63 at episode 547
# running reward: 424753.14, reward: 4275.06 at episode 548
# running reward: 425030.18, reward: 4310.28 at episode 549
# running reward: 425397.77, reward: 4315.96 at episode 550
# running reward: 425023.56, reward: 4171.90 at episode 551
# running reward: 425566.13, reward: 4375.89 at episode 552
# running reward: 425676.73, reward: 4264.48 at episode 553
# running reward: 425718.84, reward: 4267.33 at episode 554
# running reward: 425877.52, reward: 4297.75 at episode 555
# running reward: 426061.84, reward: 4293.40 at episode 556
# running reward: 425626.15, reward: 4164.31 at episode 557
# running reward: 425444.62, reward: 4226.15 at episode 558
# running reward: 425435.19, reward: 4245.79 at episode 559
# running reward: 425321.28, reward: 4234.52 at episode 560
# running reward: 425188.53, reward: 4235.52 at episode 561
# running reward: 425138.29, reward: 4223.91 at episode 562
# running reward: 425408.49, reward: 4330.79 at episode 563
# running reward: 425650.93, reward: 4295.49 at episode 564
# running reward: 425277.65, reward: 4169.53 at episode 565
# running reward: 425776.02, reward: 4374.84 at episode 566
# running reward: 425682.08, reward: 4216.81 at episode 567
# running reward: 425854.45, reward: 4299.09 at episode 568
# running reward: 425729.97, reward: 4219.73 at episode 569
# running reward: 425778.44, reward: 4277.70 at episode 570
# running reward: 425302.25, reward: 4145.56 at episode 571
# running reward: 425461.74, reward: 4304.69 at episode 572
# running reward: 425746.89, reward: 4319.98 at episode 573
# running reward: 425992.13, reward: 4306.19 at episode 574
# running reward: 426229.67, reward: 4301.08 at episode 575
# running reward: 425730.06, reward: 4142.91 at episode 576
# running reward: 425325.01, reward: 4171.09 at episode 577
# running reward: 425461.72, reward: 4300.65 at episode 578
# running reward: 425602.28, reward: 4291.50 at episode 579
# running reward: 425660.04, reward: 4255.77 at episode 580
# running reward: 425664.17, reward: 4263.99 at episode 581
# running reward: 425661.19, reward: 4249.59 at episode 582
# running reward: 426102.78, reward: 4352.60 at episode 583
# running reward: 425884.58, reward: 4198.72 at episode 584
# running reward: 425690.66, reward: 4229.29 at episode 585
# running reward: 425680.94, reward: 4255.59 at episode 586
# running reward: 425592.54, reward: 4239.38 at episode 587
# running reward: 425522.49, reward: 4247.44 at episode 588
# running reward: 425806.44, reward: 4316.21 at episode 589
# running reward: 425896.52, reward: 4272.49 at episode 590
# running reward: 425348.09, reward: 4129.17 at episode 591
# running reward: 425380.87, reward: 4280.22 at episode 592
# running reward: 425682.35, reward: 4317.73 at episode 593
# running reward: 425631.18, reward: 4233.72 at episode 594
# running reward: 425034.21, reward: 4133.11 at episode 595
# running reward: 425158.52, reward: 4290.47 at episode 596
# running reward: 424948.28, reward: 4193.34 at episode 597
# running reward: 424925.15, reward: 4254.28 at episode 598
# running reward: 424913.46, reward: 4246.46 at episode 599
# running reward: 424831.22, reward: 4233.37 at episode 600
# running reward: 424974.11, reward: 4278.38 at episode 601
# running reward: 425312.43, reward: 4331.18 at episode 602
# running reward: 425346.83, reward: 4242.24 at episode 603
# running reward: 425532.84, reward: 4297.82 at episode 604
# running reward: 425450.36, reward: 4230.27 at episode 605
# running reward: 425492.76, reward: 4277.09 at episode 606
# running reward: 425921.33, reward: 4338.50 at episode 607
# running reward: 425809.82, reward: 4228.76 at episode 608
# running reward: 425757.47, reward: 4246.06 at episode 609
# running reward: 425714.25, reward: 4256.79 at episode 610
# running reward: 425966.61, reward: 4319.38 at episode 611
# running reward: 426642.61, reward: 4398.63 at episode 612
# running reward: 426494.91, reward: 4217.61 at episode 613
# running reward: 426429.57, reward: 4257.77 at episode 614
# running reward: 426278.80, reward: 4220.38 at episode 615
# running reward: 426071.13, reward: 4217.16 at episode 616
# running reward: 425674.44, reward: 4177.80 at episode 617
# running reward: 425387.02, reward: 4207.94 at episode 618
# running reward: 425060.41, reward: 4178.35 at episode 619
# running reward: 424653.15, reward: 4176.95 at episode 620
# running reward: 424952.52, reward: 4325.16 at episode 621
# running reward: 425453.39, reward: 4344.72 at episode 622
# running reward: 425965.68, reward: 4361.77 at episode 623
# running reward: 426496.71, reward: 4369.77 at episode 624
# running reward: 426820.64, reward: 4318.77 at episode 625
# running reward: 426621.11, reward: 4219.75 at episode 626
# running reward: 426118.40, reward: 4149.39 at episode 627
# running reward: 425871.15, reward: 4233.45 at episode 628
# running reward: 425845.31, reward: 4243.85 at episode 629
# running reward: 426264.60, reward: 4364.22 at episode 630
# running reward: 426203.00, reward: 4235.45 at episode 631
# running reward: 426292.52, reward: 4290.00 at episode 632
# running reward: 426375.96, reward: 4280.91 at episode 633
# running reward: 426023.38, reward: 4169.63 at episode 634
# running reward: 425677.15, reward: 4196.12 at episode 635
# running reward: 425820.61, reward: 4301.10 at episode 636
# running reward: 426194.53, reward: 4344.35 at episode 637
# running reward: 426649.94, reward: 4348.19 at episode 638
# running reward: 426934.30, reward: 4322.51 at episode 639
# running reward: 426680.08, reward: 4230.71 at episode 640
# running reward: 426828.71, reward: 4275.73 at episode 641
# running reward: 426770.37, reward: 4261.50 at episode 642
# running reward: 426799.85, reward: 4256.22 at episode 643
# running reward: 426499.20, reward: 4204.63 at episode 644
# running reward: 426341.56, reward: 4246.65 at episode 645
# running reward: 426344.33, reward: 4269.67 at episode 646
# running reward: 426045.22, reward: 4195.22 at episode 647
# running reward: 425438.93, reward: 4126.90 at episode 648
# running reward: 425185.16, reward: 4216.73 at episode 649
# running reward: 425530.90, reward: 4342.38 at episode 650
# running reward: 425539.79, reward: 4240.92 at episode 651
# running reward: 426019.15, reward: 4360.65 at episode 652
# running reward: 426312.15, reward: 4313.75 at episode 653
# running reward: 426184.51, reward: 4215.11 at episode 654
# running reward: 426100.45, reward: 4251.37 at episode 655
# running reward: 426385.28, reward: 4329.03 at episode 656
# running reward: 426245.68, reward: 4220.28 at episode 657
# running reward: 426370.52, reward: 4305.91 at episode 658
# running reward: 426809.38, reward: 4366.20 at episode 659
# running reward: 426947.42, reward: 4278.93 at episode 660
# running reward: 426712.72, reward: 4206.33 at episode 661
# running reward: 426504.96, reward: 4232.77 at episode 662
# running reward: 426577.27, reward: 4278.07 at episode 663
# running reward: 426520.01, reward: 4262.12 at episode 664
# running reward: 426245.00, reward: 4195.12 at episode 665
# running reward: 426443.15, reward: 4324.04 at episode 666
# running reward: 426453.15, reward: 4257.83 at episode 667
# running reward: 426419.50, reward: 4251.95 at episode 668
# running reward: 426526.60, reward: 4291.53 at episode 669
# running reward: 426767.96, reward: 4319.03 at episode 670
# running reward: 426293.22, reward: 4155.64 at episode 671
# running reward: 426076.20, reward: 4222.70 at episode 672
# running reward: 426490.18, reward: 4361.90 at episode 673
# running reward: 426971.21, reward: 4365.71 at episode 674
# running reward: 427625.80, reward: 4407.20 at episode 675
# running reward: 427525.79, reward: 4245.88 at episode 676
# running reward: 427069.47, reward: 4161.67 at episode 677
# running reward: 427189.67, reward: 4322.93 at episode 678
# running reward: 427685.59, reward: 4370.71 at episode 679
# running reward: 427353.58, reward: 4187.64 at episode 680
# running reward: 426939.14, reward: 4186.92 at episode 681
# running reward: 426811.10, reward: 4252.35 at episode 682
# running reward: 426577.76, reward: 4216.65 at episode 683
# running reward: 426367.48, reward: 4219.68 at episode 684
# running reward: 426293.98, reward: 4258.51 at episode 685
# running reward: 426386.02, reward: 4290.65 at episode 686
# running reward: 426043.38, reward: 4181.04 at episode 687
# running reward: 426315.28, reward: 4333.65 at episode 688
# running reward: 426443.94, reward: 4278.23 at episode 689
# running reward: 426731.69, reward: 4330.52 at episode 690
# running reward: 426375.09, reward: 4176.09 at episode 691
# running reward: 426549.74, reward: 4305.41 at episode 692
# running reward: 426209.30, reward: 4193.78 at episode 693
# running reward: 425924.50, reward: 4202.34 at episode 694
# running reward: 425956.91, reward: 4278.11 at episode 695
# running reward: 426080.40, reward: 4283.47 at episode 696
# running reward: 425994.68, reward: 4242.03 at episode 697
# running reward: 426178.66, reward: 4298.47 at episode 698
# running reward: 426265.32, reward: 4276.25 at episode 699
# running reward: 426604.52, reward: 4339.57 at episode 700
# running reward: 426492.03, reward: 4234.10 at episode 701
# running reward: 426208.62, reward: 4203.25 at episode 702
# running reward: 426322.21, reward: 4286.56 at episode 703
# running reward: 426174.37, reward: 4233.16 at episode 704
# running reward: 426507.66, reward: 4340.52 at episode 705
# running reward: 426257.40, reward: 4207.54 at episode 706
# running reward: 426447.42, reward: 4310.57 at episode 707
# running reward: 426479.47, reward: 4261.36 at episode 708
# running reward: 426663.86, reward: 4296.76 at episode 709
# running reward: 426324.39, reward: 4188.28 at episode 710
# running reward: 426606.06, reward: 4339.39 at episode 711
# running reward: 426462.12, reward: 4228.85 at episode 712
# running reward: 426617.37, reward: 4305.75 at episode 713
# running reward: 426574.97, reward: 4254.43 at episode 714
# running reward: 426326.37, reward: 4202.88 at episode 715
# running reward: 426087.83, reward: 4221.01 at episode 716
# running reward: 425232.13, reward: 4107.94 at episode 717
# running reward: 425500.74, reward: 4300.95 at episode 718
# running reward: 425858.42, reward: 4320.15 at episode 719
# running reward: 425611.83, reward: 4200.83 at episode 720
# running reward: 426095.24, reward: 4370.11 at episode 721
# running reward: 426320.38, reward: 4299.02 at episode 722
# running reward: 426306.43, reward: 4259.51 at episode 723
# running reward: 426132.31, reward: 4220.61 at episode 724
# running reward: 426382.98, reward: 4329.68 at episode 725
# running reward: 426282.94, reward: 4224.14 at episode 726
# running reward: 426184.05, reward: 4246.79 at episode 727
# running reward: 425733.58, reward: 4164.75 at episode 728
# running reward: 425694.71, reward: 4265.33 at episode 729
# running reward: 425958.44, reward: 4311.82 at episode 730
# running reward: 425706.95, reward: 4195.94 at episode 731
# running reward: 425529.87, reward: 4227.66 at episode 732
# running reward: 425230.50, reward: 4187.76 at episode 733
# running reward: 425393.83, reward: 4292.23 at episode 734
# running reward: 425837.98, reward: 4352.89 at episode 735
# running reward: 425407.16, reward: 4147.07 at episode 736
# running reward: 425166.15, reward: 4205.42 at episode 737
# running reward: 425483.82, reward: 4340.41 at episode 738
# running reward: 425387.15, reward: 4215.92 at episode 739
# running reward: 425584.04, reward: 4303.44 at episode 740
# running reward: 425396.93, reward: 4210.64 at episode 741
# running reward: 425292.08, reward: 4231.27 at episode 742
# running reward: 425188.83, reward: 4236.27 at episode 743
# running reward: 424993.98, reward: 4211.22 at episode 744
# running reward: 425085.70, reward: 4278.84 at episode 745
# running reward: 425659.06, reward: 4376.61 at episode 746
# running reward: 425980.22, reward: 4309.15 at episode 747
# running reward: 425655.07, reward: 4173.08 at episode 748
# running reward: 425388.98, reward: 4212.25 at episode 749
# running reward: 425719.21, reward: 4338.22 at episode 750
# running reward: 425780.03, reward: 4267.24 at episode 751
# running reward: 425638.14, reward: 4216.02 at episode 752
# running reward: 425354.38, reward: 4189.81 at episode 753
# running reward: 425323.12, reward: 4259.75 at episode 754
# running reward: 425396.97, reward: 4279.81 at episode 755
# running reward: 425720.72, reward: 4315.15 at episode 756
# running reward: 426158.73, reward: 4354.60 at episode 757
# running reward: 426194.54, reward: 4253.40 at episode 758
# running reward: 426130.13, reward: 4256.33 at episode 759
# running reward: 426594.86, reward: 4360.97 at episode 760
# running reward: 426295.89, reward: 4182.36 at episode 761
# running reward: 426325.41, reward: 4286.09 at episode 762
# running reward: 426033.20, reward: 4187.20 at episode 763
# running reward: 426303.44, reward: 4334.63 at episode 764
# running reward: 426434.60, reward: 4285.73 at episode 765
# running reward: 426547.43, reward: 4278.60 at episode 766
# running reward: 426433.82, reward: 4243.96 at episode 767
# running reward: 426562.98, reward: 4297.18 at episode 768
# running reward: 426684.69, reward: 4290.35 at episode 769
# running reward: 426661.33, reward: 4257.85 at episode 770
# running reward: 426666.46, reward: 4266.74 at episode 771
# running reward: 426261.92, reward: 4173.87 at episode 772
# running reward: 425935.03, reward: 4201.07 at episode 773
# running reward: 426079.19, reward: 4294.21 at episode 774
# running reward: 425947.61, reward: 4234.00 at episode 775
# running reward: 426104.87, reward: 4298.65 at episode 776
# running reward: 426104.86, reward: 4261.03 at episode 777
# running reward: 426609.75, reward: 4370.36 at episode 778
# running reward: 426459.51, reward: 4220.78 at episode 779
# running reward: 426671.91, reward: 4316.18 at episode 780
# running reward: 426653.17, reward: 4250.84 at episode 781
# running reward: 426168.19, reward: 4173.20 at episode 782
# running reward: 425768.18, reward: 4166.69 at episode 783
# running reward: 425365.05, reward: 4181.32 at episode 784
# running reward: 425468.92, reward: 4281.58 at episode 785
# running reward: 425758.27, reward: 4324.60 at episode 786
# running reward: 425626.95, reward: 4217.21 at episode 787
# running reward: 425587.36, reward: 4252.55 at episode 788
# running reward: 425328.70, reward: 4198.30 at episode 789
# running reward: 425404.74, reward: 4269.11 at episode 790
# running reward: 425424.80, reward: 4261.43 at episode 791
# running reward: 425578.51, reward: 4295.99 at episode 792
# running reward: 425762.85, reward: 4282.91 at episode 793
# running reward: 425700.65, reward: 4238.08 at episode 794
# running reward: 425679.83, reward: 4255.80 at episode 795
# running reward: 425774.10, reward: 4279.40 at episode 796
# running reward: 426076.82, reward: 4327.10 at episode 797
# running reward: 426336.65, reward: 4308.10 at episode 798
# running reward: 426120.36, reward: 4205.51 at episode 799
# running reward: 425995.69, reward: 4245.00 at episode 800
# running reward: 425405.62, reward: 4120.74 at episode 801
# running reward: 425521.58, reward: 4307.14 at episode 802
# running reward: 425600.37, reward: 4269.00 at episode 803
# running reward: 425874.00, reward: 4318.45 at episode 804
# running reward: 426037.45, reward: 4290.17 at episode 805
# running reward: 425106.18, reward: 4061.25 at episode 806
# running reward: 425085.44, reward: 4252.93 at episode 807
# running reward: 425039.56, reward: 4231.72 at episode 808
# running reward: 424755.68, reward: 4200.13 at episode 809
# running reward: 424759.07, reward: 4243.31 at episode 810
# running reward: 425044.69, reward: 4314.38 at episode 811
# running reward: 424724.98, reward: 4172.55 at episode 812
# running reward: 424353.66, reward: 4174.55 at episode 813
# running reward: 424405.61, reward: 4268.87 at episode 814
# running reward: 424654.34, reward: 4291.66 at episode 815
# running reward: 424539.50, reward: 4208.68 at episode 816
# running reward: 424422.29, reward: 4226.60 at episode 817
# running reward: 424574.94, reward: 4281.96 at episode 818
# running reward: 424860.84, reward: 4298.55 at episode 819
# running reward: 424286.04, reward: 4122.73 at episode 820
# running reward: 424583.07, reward: 4321.32 at episode 821
# running reward: 424687.80, reward: 4253.22 at episode 822
# running reward: 424750.85, reward: 4265.71 at episode 823
# running reward: 424740.93, reward: 4246.02 at episode 824
# running reward: 424473.61, reward: 4181.23 at episode 825
# running reward: 424968.85, reward: 4372.75 at episode 826
# running reward: 424675.31, reward: 4155.20 at episode 827
# running reward: 424418.61, reward: 4214.48 at episode 828
# running reward: 423952.20, reward: 4141.58 at episode 829
# running reward: 424082.57, reward: 4282.60 at episode 830
# running reward: 424348.39, reward: 4286.38 at episode 831
# running reward: 424290.26, reward: 4232.10 at episode 832
# running reward: 424146.66, reward: 4213.05 at episode 833
# running reward: 423744.65, reward: 4149.98 at episode 834
# running reward: 423429.67, reward: 4183.72 at episode 835
# running reward: 423649.81, reward: 4295.00 at episode 836
# running reward: 424156.20, reward: 4339.29 at episode 837
# running reward: 424010.20, reward: 4194.21 at episode 838
# running reward: 424391.19, reward: 4332.90 at episode 839
# running reward: 424602.23, reward: 4273.56 at episode 840
# running reward: 424285.98, reward: 4179.87 at episode 841
# running reward: 424767.35, reward: 4354.54 at episode 842
# running reward: 424979.06, reward: 4285.85 at episode 843
# running reward: 424628.83, reward: 4153.06 at episode 844
# running reward: 424344.25, reward: 4199.58 at episode 845
# running reward: 424248.43, reward: 4233.40 at episode 846
# running reward: 423824.31, reward: 4136.01 at episode 847
# running reward: 423371.17, reward: 4159.56 at episode 848
# running reward: 423335.90, reward: 4230.45 at episode 849
# running reward: 423300.17, reward: 4226.59 at episode 850
# running reward: 423400.63, reward: 4257.77 at episode 851
# running reward: 423603.65, reward: 4269.97 at episode 852
# running reward: 423601.83, reward: 4240.02 at episode 853
# running reward: 423686.18, reward: 4257.64 at episode 854
# running reward: 423939.93, reward: 4288.00 at episode 855
# running reward: 423853.94, reward: 4209.08 at episode 856
# running reward: 423767.00, reward: 4226.76 at episode 857
# running reward: 423938.40, reward: 4277.06 at episode 858
# running reward: 424078.37, reward: 4262.93 at episode 859
# running reward: 424232.94, reward: 4267.28 at episode 860
# running reward: 423791.04, reward: 4144.89 at episode 861
# running reward: 424133.10, reward: 4330.51 at episode 862
# running reward: 424693.21, reward: 4358.40 at episode 863
# running reward: 424785.64, reward: 4253.32 at episode 864
# running reward: 425075.67, reward: 4304.94 at episode 865
# running reward: 425693.57, reward: 4391.20 at episode 866
# running reward: 425480.10, reward: 4192.39 at episode 867
# running reward: 424946.79, reward: 4130.03 at episode 868
# running reward: 424479.07, reward: 4168.16 at episode 869
# running reward: 423992.70, reward: 4138.20 at episode 870
# running reward: 423615.24, reward: 4172.11 at episode 871
# running reward: 422961.81, reward: 4093.41 at episode 872
# running reward: 423131.29, reward: 4296.49 at episode 873
# running reward: 422974.88, reward: 4190.92 at episode 874
# running reward: 422880.56, reward: 4208.76 at episode 875
# running reward: 422713.83, reward: 4199.08 at episode 876
# running reward: 422649.05, reward: 4203.43 at episode 877
# running reward: 422894.00, reward: 4284.64 at episode 878
# running reward: 422999.80, reward: 4246.70 at episode 879
# running reward: 422951.07, reward: 4226.23 at episode 880
# running reward: 422656.43, reward: 4156.66 at episode 881
# running reward: 422569.04, reward: 4216.58 at episode 882
# running reward: 422627.61, reward: 4242.37 at episode 883
# running reward: 422613.07, reward: 4230.28 at episode 884
# running reward: 422802.07, reward: 4256.19 at episode 885
# running reward: 423199.80, reward: 4316.17 at episode 886
# running reward: 422730.35, reward: 4118.98 at episode 887
# running reward: 423065.57, reward: 4314.77 at episode 888
# running reward: 423534.42, reward: 4326.23 at episode 889
# running reward: 423705.97, reward: 4258.54 at episode 890
# running reward: 423298.86, reward: 4140.10 at episode 891
# running reward: 423564.68, reward: 4303.42 at episode 892
# running reward: 423856.48, reward: 4291.93 at episode 893
# running reward: 423502.57, reward: 4150.11 at episode 894
# running reward: 423615.90, reward: 4280.73 at episode 895
# running reward: 424353.63, reward: 4405.22 at episode 896
# running reward: 424273.78, reward: 4195.91 at episode 897
# running reward: 424413.28, reward: 4282.49 at episode 898
# running reward: 424773.14, reward: 4312.35 at episode 899
# running reward: 424406.58, reward: 4159.23 at episode 900
# running reward: 424598.95, reward: 4301.82 at episode 901
# running reward: 424694.98, reward: 4259.91 at episode 902
# running reward: 424458.70, reward: 4184.91 at episode 903
# running reward: 424421.11, reward: 4256.39 at episode 904
# running reward: 424212.87, reward: 4195.30 at episode 905
# running reward: 424272.58, reward: 4254.44 at episode 906
# running reward: 424416.54, reward: 4267.33 at episode 907
# running reward: 424280.40, reward: 4216.05 at episode 908
# running reward: 424743.02, reward: 4349.14 at episode 909
# running reward: 424350.22, reward: 4150.99 at episode 910
# running reward: 424388.68, reward: 4250.52 at episode 911
# running reward: 424096.68, reward: 4183.75 at episode 912
# running reward: 423920.11, reward: 4204.07 at episode 913
# running reward: 424168.99, reward: 4307.67 at episode 914
# running reward: 424374.82, reward: 4280.63 at episode 915
# running reward: 424549.16, reward: 4283.78 at episode 916
# running reward: 424190.01, reward: 4156.34 at episode 917
# running reward: 423922.30, reward: 4187.57 at episode 918
# running reward: 424114.74, reward: 4287.71 at episode 919
# running reward: 423931.08, reward: 4196.63 at episode 920
# running reward: 424429.60, reward: 4355.59 at episode 921
# running reward: 424301.91, reward: 4206.76 at episode 922
# running reward: 424958.66, reward: 4401.24 at episode 923
# running reward: 424866.42, reward: 4204.63 at episode 924
# running reward: 424612.14, reward: 4194.42 at episode 925
# running reward: 424191.12, reward: 4155.56 at episode 926
# running reward: 424411.88, reward: 4293.86 at episode 927
# running reward: 423990.04, reward: 4141.55 at episode 928
# running reward: 423596.47, reward: 4177.48 at episode 929
# running reward: 423452.37, reward: 4211.85 at episode 930
# running reward: 423815.09, reward: 4318.69 at episode 931
# running reward: 424488.89, reward: 4380.69 at episode 932
# running reward: 424689.73, reward: 4269.43 at episode 933
# running reward: 424848.69, reward: 4282.27 at episode 934
# running reward: 425039.96, reward: 4287.37 at episode 935
# running reward: 424954.73, reward: 4219.58 at episode 936
# running reward: 424985.70, reward: 4256.52 at episode 937
# running reward: 424461.58, reward: 4132.14 at episode 938
# running reward: 424450.12, reward: 4275.96 at episode 939
# running reward: 424760.69, reward: 4296.82 at episode 940
# running reward: 424254.94, reward: 4128.32 at episode 941
# running reward: 424853.67, reward: 4397.71 at episode 942
# running reward: 425290.55, reward: 4322.96 at episode 943
# running reward: 425577.90, reward: 4311.12 at episode 944
# running reward: 425272.34, reward: 4184.39 at episode 945
# running reward: 425230.70, reward: 4237.90 at episode 946
# running reward: 425463.70, reward: 4307.39 at episode 947
# running reward: 425086.88, reward: 4166.17 at episode 948
# running reward: 424604.87, reward: 4153.69 at episode 949
# running reward: 424810.74, reward: 4304.95 at episode 950
# running reward: 424899.35, reward: 4264.00 at episode 951
# running reward: 425189.83, reward: 4310.34 at episode 952
# running reward: 425371.51, reward: 4283.39 at episode 953
# running reward: 425725.23, reward: 4334.08 at episode 954
# running reward: 425732.63, reward: 4249.77 at episode 955
# running reward: 425929.93, reward: 4298.23 at episode 956
# running reward: 425806.58, reward: 4232.20 at episode 957
# running reward: 426040.90, reward: 4300.99 at episode 958
# running reward: 425547.26, reward: 4149.69 at episode 959
# running reward: 425655.60, reward: 4308.20 at episode 960
# running reward: 425909.22, reward: 4291.45 at episode 961
# running reward: 426153.13, reward: 4322.29 at episode 962
# running reward: 426374.01, reward: 4291.54 at episode 963
# running reward: 426136.38, reward: 4207.35 at episode 964
# running reward: 425692.46, reward: 4166.99 at episode 965
# running reward: 425553.20, reward: 4243.47 at episode 966
# running reward: 425817.79, reward: 4320.51 at episode 967
# running reward: 426250.21, reward: 4346.09 at episode 968
# running reward: 426809.68, reward: 4377.40 at episode 969
# running reward: 426865.46, reward: 4261.74 at episode 970
# running reward: 426759.76, reward: 4251.72 at episode 971
# running reward: 426827.91, reward: 4284.79 at episode 972
# running reward: 426992.50, reward: 4303.29 at episode 973
# running reward: 426463.01, reward: 4138.08 at episode 974
# running reward: 425854.08, reward: 4146.72 at episode 975
# running reward: 425863.44, reward: 4271.93 at episode 976
# running reward: 425866.59, reward: 4252.37 at episode 977
# running reward: 425971.92, reward: 4292.81 at episode 978
# running reward: 426048.00, reward: 4268.80 at episode 979
# running reward: 426069.51, reward: 4263.33 at episode 980
# running reward: 425214.36, reward: 4066.61 at episode 981
# running reward: 425372.47, reward: 4312.98 at episode 982
# running reward: 425787.76, reward: 4357.59 at episode 983
# running reward: 425963.14, reward: 4276.11 at episode 984
# running reward: 426157.30, reward: 4294.65 at episode 985
# running reward: 425957.29, reward: 4214.05 at episode 986
# running reward: 426026.81, reward: 4283.38 at episode 987
# running reward: 426287.34, reward: 4309.13 at episode 988
# running reward: 426553.63, reward: 4315.43 at episode 989
# running reward: 425822.81, reward: 4094.95 at episode 990
# running reward: 425959.90, reward: 4323.34 at episode 991
# running reward: 426128.98, reward: 4277.30 at episode 992
# running reward: 426100.78, reward: 4251.75 at episode 993
# running reward: 426170.67, reward: 4284.11 at episode 994
# running reward: 425803.15, reward: 4165.39 at episode 995
# running reward: 426126.07, reward: 4353.28 at episode 996
# running reward: 425814.53, reward: 4173.08 at episode 997
# running reward: 426042.22, reward: 4330.50 at episode 998
# running reward: 426287.54, reward: 4300.22 at episode 999
# running reward: 425665.29, reward: 4110.14 at episode 1000
# Reached episode 1000!

# %%
fig, ax = plt.subplots()
ax.plot(epi, Reward)

ax.set(xlabel='Episode', ylabel='Reward',
       title='Reward vs. Episode')
ax.grid()
plt.show()
